# %% [markdown]
# # Demo Notebook — YOLOv8
#
# This notebook tests the YOLOPredictor if ultralytics is installed.

# %%
from PIL import Image
from model.predict import Predictor

p = Predictor(device='cpu')
img = Image.open('examples/sample.jpg') if __import__('os').path.exists('examples/sample.jpg') else Image.new('RGB',(256,256),'white')
print('Predictions:', p.predict(img))
